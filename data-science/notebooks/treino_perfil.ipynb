# %% [markdown]
# # 🧪 Notebook 02: Treinamento do Classificador de Perfil Financeiro
#
# Este notebook tem como objetivo treinar um modelo de Machine Learning (Random Forest / Gradient Boosting) para classificar o comportamento e perfil financeiro do usuário em três categorias de risco (`Saudavel`, `Em observacao`, `Em risco`).

# %%
# ==============================================================================
# 1. Importação de bibliotecas essenciais
# ==============================================================================
# import pandas as pd
# import numpy as np
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.model_selection import train_test_split
# from sklearn.preprocessing import OrdinalEncoder
# from sklearn.metrics import classification_report
# import joblib

# %%
# ==============================================================================
# 2. Carregamento e Pré-processamento dos dados de perfis
# ==============================================================================
# df = pd.read_csv('../data/perfis_usuarios_treino.csv')
# # Aplicar Encoding na coluna 'frequencia_poupanca' (Baixa: 0, Media: 1, Alta: 2)
# print(df.head())

# %%
# ==============================================================================
# 3. Treinamento do Modelo de Perfil (Random Forest Classifier)
# ==============================================================================
# features = ['renda_mensal', 'nivel_endividamento', 'frequencia_poupanca_encoded', 
#             'gasto_alimentacao', 'gasto_transporte', 'gasto_lazer', 'gasto_moradia']
# target = 'classe_perfil'
# 
# model = RandomForestClassifier(n_estimators=100, random_state=42)
# model.fit(df[features], df[target])

# %%
# ==============================================================================
# 4. Exportação do modelo treinado para data-science/models/
# ==============================================================================
# CRÍTICO: O artefato DEVE ser salvo em '../models/modelo_perfil.joblib'
# joblib.dump(model, '../models/modelo_perfil.joblib')
# print("Modelo exportado com sucesso para ../models/modelo_perfil.joblib")
